# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth

SPOTIPY_CLIENT_ID = "0be1da36f0594963b21a361ae5bd5d07"
SPOTIPY_CLIENT_SECRET = "093f6e330b414e4cbda05e95dbc0bef7"
SPOTIPY_REDIRECT_URI = 'http://localhost:8080/callback'

client_id = SPOTIPY_CLIENT_ID
client_secret = SPOTIPY_CLIENT_SECRET
redirect_uri = SPOTIPY_REDIRECT_URI


client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

def get_global_top_50():
    # Global Top 50 Playlist URI (this URI is subject to change)
    playlist_uri = 'spotify:playlist:37i9dQZEVXbMDoHDwVN2tF'

    # Fetch playlist
    results = sp.playlist_tracks(playlist_uri)

    songs_data = []
    for idx, item in enumerate(results['items']):
        track = item['track']
        song_info = {
            'title': track['name'],
            'artist': track['artists'][0]['name'],
            'album': track['album']['name'],
            'popularity': track['popularity'],  # Use 'popularity' instead of 'streaming_numbers'
            # Trending status requires historical data comparison, placeholder added
            'trending': 'N/A'
        }
        songs_data.append(song_info)

    # Convert list of dictionaries to DataFrame
    return pd.DataFrame(songs_data)

# Get the top 50 songs and convert to DataFrame
top_50_df = get_global_top_50()
top_50_df
# Out:
#                                                 title          artist  \
# 0                     All I Want for Christmas Is You    Mariah Carey
# 1                     Last Christmas - Single Version           Wham!
# 2                   Rockin' Around The Christmas Tree      Brenda Lee
# 3                                              greedy      Tate McRae
# 4                                    Jingle Bell Rock     Bobby Helms
# 5                               My Love Mine All Mine          Mitski
# 6                                       Santa Tell Me   Ariana Grande
# 7         It's Beginning to Look a Lot like Christmas   Michael Bublé
# 8                                        Cruel Summer    Taylor Swift
# 9            It's the Most Wonderful Time of the Year   Andy Williams
# 10                                        Lovin On Me     Jack Harlow
# 11                                            Snowman             Sia
# 12             Let It Snow! Let It Snow! Let It Snow!     Dean Martin
# 13     One Of The Girls (with JENNIE, Lily Rose Depp)      The Weeknd
# 14                                Underneath the Tree  Kelly Clarkson
# 15                              Holly Jolly Christmas   Michael Bublé
# 16                Seven (feat. Latto) (Explicit Ver.)       Jung Kook
# 17                                          La Diabla            Xavi
# 18                                      Feliz Navidad  José Feliciano
# 19                                 Paint The Town Red        Doja Cat
# 20                                   I Wanna Be Yours  Arctic Monkeys
# 21                                        Sleigh Ride    The Ronettes
# 22                                              QLONA         KAROL G
# 23                                        Si No Estás  iñigo quintero
# 24                                        PERRO NEGRO       Bad Bunny
# 25                                          Strangers     Kenya Grace
# 26                                          Mistletoe   Justin Bieber
# 27                               Standing Next to You       Jung Kook
# 28                                              Water            Tyla
# 29                                       HARLEY QUINN   Fuerza Regida
# 30                                           Que Onda        Calle 24
# 31                                        Agora Hills        Doja Cat
# 32                                               LUNA            Feid
# 33                                       Stick Season      Noah Kahan
# 34                                            vampire  Olivia Rodrigo
# 35                                            Starboy      The Weeknd
# 36                                         La Víctima            Xavi
# 37                                           Daylight   David Kushner
# 38                            A Holly Jolly Christmas       Burl Ives
# 39                                        Según Quién          Maluma
# 40                                          Kill Bill             SZA
# 41         Happy Xmas (War Is Over) - Remastered 2010     John Lennon
# 42       Surround Sound (feat. 21 Savage & Baby Tate)             JID
# 43                                     Pehle Bhi Main   Vishal Mishra
# 44  Let It Snow! Let It Snow! Let It Snow! (with T...   Frank Sinatra
# 45                                           BELLAKEO      Peso Pluma
# 46  What Was I Made For? [From The Motion Picture ...   Billie Eilish
# 47                                   The Night We Met      Lord Huron
# 48                                          As It Was    Harry Styles
# 49        The Christmas Song (Merry Christmas To You)   Nat King Cole
#
#                                                 album  popularity trending
# 0                                     Merry Christmas         100      N/A
# 1         The Singles: Echoes from the Edge of Heaven          89      N/A
# 2                     Merry Christmas From Brenda Lee          98      N/A
# 3                                              greedy          99      N/A
# 4   Jingle Bell Rock/Captain Santa Claus (And His ...          94      N/A
# 5              The Land Is Inhospitable and So Are We          98      N/A
# 6                                       Santa Tell Me          96      N/A
# 7                  Christmas (Deluxe Special Edition)          87      N/A
# 8                                               Lover          98      N/A
# 9                   The Andy Williams Christmas Album          79      N/A
# 10                                        Lovin On Me          97      N/A
# 11             Everyday Is Christmas (Deluxe Edition)          94      N/A
# 12                                   A Winter Romance          95      N/A
# 13  The Idol Episode 4 (Music from the HBO Origina...          94      N/A
# 14                                     Wrapped In Red          86      N/A
# 15                                          Christmas          83      N/A
# 16                                             GOLDEN          90      N/A
# 17                                          La Diabla          88      N/A
# 18                                      Feliz Navidad          88      N/A
# 19                                            Scarlet          88      N/A
# 20                                                 AM          95      N/A
# 21                                        Sleigh Ride          83      N/A
# 22                MAÑANA SERÁ BONITO (BICHOTA SEASON)          93      N/A
# 23                                        Si No Estás          97      N/A
# 24                nadie sabe lo que va a pasar mañana          96      N/A
# 25                                          Strangers          96      N/A
# 26               Under The Mistletoe (Deluxe Edition)          92      N/A
# 27                                             GOLDEN          97      N/A
# 28                                              Water          95      N/A
# 29                          Pa las Baby's Y Belikeada          95      N/A
# 30                                           Que Onda          94      N/A
# 31                                            Scarlet          84      N/A
# 32                                     FERXXOCALIPSIS          88      N/A
# 33                                       Stick Season          93      N/A
# 34                                               GUTS          94      N/A
# 35                                            Starboy          94      N/A
# 36                                         La Víctima          90      N/A
# 37                                           Daylight          94      N/A
# 38                       Have A Holly Jolly Christmas          91      N/A
# 39                                           Don Juan          90      N/A
# 40                                                SOS          92      N/A
# 41                                      Signature Box          91      N/A
# 42               The Forever Story (Extended Version)          91      N/A
# 43                                             ANIMAL          87      N/A
# 44                         Christmas Songs by Sinatra          90      N/A
# 45                                           BELLAKEO          85      N/A
# 46  What Was I Made For? [From The Motion Picture ...          93      N/A
# 47                                     Strange Trails          82      N/A
# 48                                      Harry's House          94      N/A
# 49                            The Nat King Cole Story          69      N/A

# %%
top_50_df.to_csv("top_50.csv")

# %%
top_50_df.iloc[:1,:]
# Out:
#                              title        artist            album  \
# 0  All I Want for Christmas Is You  Mariah Carey  Merry Christmas
#
#   streaming_numbers trending
# 0               N/A      N/A

# %%
# Initialize the Spotipy client
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id, client_secret=client_secret, redirect_uri=redirect_uri, scope='user-library-read'))

# Replace with the song and artist you want to search for
song_name = "All I Want for Christmas Is You"
artist_name = "Mariah Carey"

results = sp.search(q=f'track:{song_name} artist:{artist_name}', type='track')

# Extract the track URI and get the number of streams
if len(results['tracks']['items']) > 0:
    track_uri = results['tracks']['items'][0]['uri']
    audio_analysis = sp.audio_analysis(track_uri)
    num_streams = audio_analysis['track']['num_streams']
    print(f"The song '{song_name}' by '{artist_name}' has {num_streams} streams.")
else:
    print("Song not found.")

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results['tracks']['next']
# Out:
# 'https://api.spotify.com/v1/search?query=track%3AAll+I+Want+for+Christmas+Is+You+artist%3AMariah+Carey&type=track&offset=10&limit=10'

# %% [markdown]
# ### wrapped

# %%
# Instantiate Object
SPOTIPY_CLIENT_ID = client_id
SPOTIPY_CLIENT_SECRET = client_secret
# SPOTIPY_REDIRECT_URI = 'https://inferential-spotify-dashboard.streamlit.app/'
SPOTIPY_REDIRECT_URI = 'http://localhost:8080/callback' # for testing
SCOPE= 'user-library-read user-library-modify playlist-read-private playlist-modify-private user-top-read'

#Initialize the Spotify client
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=SPOTIPY_CLIENT_ID,
        client_secret=SPOTIPY_CLIENT_SECRET,
        redirect_uri=SPOTIPY_REDIRECT_URI,
        scope=SCOPE,
    )
    )

# %%
query = f"{song_name} artist:{artist_name}"

# Search for the song by name and artist
results = sp.search(q=query, type='track', limit=1)

# Check if any tracks were found
if results['tracks']['items']:
    track = results['tracks']['items'][0]
    track_id = track['id']

    # Get audio features for the track
    audio_features = sp.audio_features(track_id)

    if audio_features:
        # Extract the relevant audio features
        features = audio_features[0]
        feature_names = [
            'danceability', 'energy', 'key', 'loudness', 'mode', 
            'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'duration_ms'
        ]

        # Create a list of audio feature values
        feature_values = [features[feature] for feature in feature_names]

        # Get additional track information
        artist_id = track['artists'][0]['id']
        album_id = track['album']['id']
        popularity = track['popularity']
        explicit = track['explicit']
        album_cover_url = track['album']['images'][0]['url']

        # Get artist information
        artist = sp.artist(artist_id)
        artist_photo_url = artist['images'][0]['url']

        # Store all the information in a dictionary
        track_info = {
            'song_name': song_name,
            'artist_name': artist_name,
            'feature_values': feature_values,
            'popularity': popularity,
            'explicit': explicit,
            'album_cover_url': album_cover_url,
            'artist_photo_url': artist_photo_url,
            "feature_values" : feature_values,
        }

        print(track_info)
# Out:
# {'song_name': 'Mast Magan', 'artist_name': 'Arijit Singh, Chinmayi', 'feature_values': [0.659, 0.774, 7, -7.014, 1, 0.0372, 0.606, 0.000333, 0.185, 0.883, 82.995, 280161], 'popularity': 74, 'explicit': False, 'album_cover_url': 'https://i.scdn.co/image/ab67616d0000b273c7b8d39b1e113845906984ab', 'artist_photo_url': 'https://i.scdn.co/image/ab6761610000e5eb0261696c5df3be99da6ed3f3'}
# [0.659, 0.774, 7, -7.014, 1, 0.0372, 0.606, 0.000333, 0.185, 0.883, 82.995, 280161]

# %%
# Out:
# {'spotify': 'https://open.spotify.com/artist/24eDfi2MSYo3A87hCcgpIL'}
